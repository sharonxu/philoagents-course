# %%
from langchain_core.documents import Document

from philoagents.application import LongTermMemoryRetriever
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# OPIK: Configuration saved to file: /Users/sharonxu/.opik.config
# OPIK: Configuration completed successfully. Traces will be logged to 'philoagents_course' project. To change the destination project, see: https://www.comet.com/docs/opik/tracing/log_traces#configuring-the-project-name
# 2025-12-10 03:56:55.635 | INFO     | philoagents.infrastructure.opik_utils:configure:30 - Opik configured successfully using workspace 'sharon-xu'
# /Users/sharonxu/miniconda3/envs/dl/lib/python3.12/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
from philoagents.config import settings

# Override MongoDB connection string
settings.MONGO_URI = (
    "mongodb://philoagents:philoagents@localhost:27017/?directConnection=true"
)

# %%
def print_memories(memories: list[Document]) -> None:
    for i, memory in enumerate(memories):
        print("-" * 100)
        print(f"Memory {i + 1}:")
        print(f"{i + 1}. {memory.page_content[:100]}")
        print(f"Source: {memory.metadata['source']}")
        print("-" * 100)

# %%
retriever = LongTermMemoryRetriever.build_from_settings()

memories = retriever("Socrates")
print_memories(memories)
# Out:
# 2025-12-10 03:57:47.010 | INFO     | philoagents.application.rag.retrievers:get_retriever:30 - Initializing retriever | model: sentence-transformers/all-MiniLM-L6-v2 | device: cpu | top_k: 3
# ----------------------------------------------------------------------------------------------------
# Memory 1:
# 1. === Aristophanes and other sources ===
# Writers of Athenian comedy, including Aristophanes, also comm
# Source: https://en.wikipedia.org/wiki/Socrates
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Memory 2:
# 2. 2. The Socratic problem: Who was Socrates really?
# Source: https://plato.stanford.edu/entries/socrates/
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Memory 3:
# 3. Xenophon's and Plato's accounts differ in their presentations of Socrates as a person. Xenophon's So
# Source: https://en.wikipedia.org/wiki/Socrates
# ----------------------------------------------------------------------------------------------------

# %%
memories = retriever("Turing")
print_memories(memories)
# Out:
# ----------------------------------------------------------------------------------------------------
# Memory 1:
# 1. AlanTuring.net – Turing Archive for the History of Computing by Jack Copeland
# Alan Turing site maint
# Source: https://en.wikipedia.org/wiki/Alan_Turing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Memory 2:
# 2. The appearance of this paper, Turing's first foray into a journal of
# philosophy, was stimulated by h
# Source: https://plato.stanford.edu/entries/turing/
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Memory 3:
# 3. Nevertheless Turing's purpose was to embody the most general
# mechanical process as carried out by a
# Source: https://plato.stanford.edu/entries/turing/
# ----------------------------------------------------------------------------------------------------
